# %% [markdown]
# # Update Paths in train.txt / val.txt
#
# 將 `train.txt` 和 `val.txt` 裡的路徑前綴換成 server 上的路徑。

# %%
from pathlib import Path

# ── 設定 ──────────────────────────────────────────────────
# 要取代的舊路徑前綴（本機）
OLD_PREFIX = "/Users/tony.tu/Desktop/戴承智慧/thyroid/yolo_data"

# 換成的新路徑前綴（server 上的路徑）
NEW_PREFIX = "/root/Desktop/thyroid/yolo_data"   # ← 改這裡
version = "v4"  # ← 改這裡
# 要處理的 txt 檔案（可以加更多）
TXT_FILES = [
    Path(f"od/{version}/train.txt"),
    Path(f"od/{version}/val.txt"),
    Path(f"od/{version}/multiple_val.txt"),
]

# 預覽模式
DRY_RUN = True

# %%
# 預覽
for txt_file in TXT_FILES:
    if not txt_file.exists():
        print(f"[SKIP] 找不到：{txt_file}")
        continue
    lines = txt_file.read_text().strip().splitlines()
    print(f"\n{txt_file}  ({len(lines)} 筆)")
    print(f"  舊：{lines[0]}")
    print(f"  新：{lines[0].replace(OLD_PREFIX, NEW_PREFIX, 1)}")
# Out:
# od/v4/train.txt  (34213 筆)
#   舊：/Users/tony.tu/Desktop/戴承智慧/thyroid/yolo_data/od/v4/images/3c53bbc2f24e91b75d3db806b46dd9e3_left.png
#   新：/root/Desktop/thyroid/yolo_data/od/v4/images/3c53bbc2f24e91b75d3db806b46dd9e3_left.png
#
# od/v4/val.txt  (2364 筆)
#   舊：/Users/tony.tu/Desktop/戴承智慧/thyroid/yolo_data/od/v4/images/d391e75a9b981397e84339c885c864da_left.png
#   新：/root/Desktop/thyroid/yolo_data/od/v4/images/d391e75a9b981397e84339c885c864da_left.png
#
# od/v4/multiple_val.txt  (116 筆)
#   舊：/Users/tony.tu/Desktop/戴承智慧/thyroid/yolo_data/od/v4/images/93effacee0f8749285b35bacfdd9f2e6_right.png
#   新：/root/Desktop/thyroid/yolo_data/od/v4/images/93effacee0f8749285b35bacfdd9f2e6_right.png

# %%
DRY_RUN = False  # 確認後改為 False

if DRY_RUN:
    print("DRY RUN，不會修改任何檔案")
else:
    for txt_file in TXT_FILES:
        if not txt_file.exists():
            print(f"[SKIP] 找不到：{txt_file}")
            continue
        content = txt_file.read_text()
        new_content = content.replace(OLD_PREFIX, NEW_PREFIX)
        txt_file.write_text(new_content)
        n = content.count(OLD_PREFIX)
        print(f"{txt_file}: 取代 {n} 筆")
    print("完成")
# Out:
# od/v4/train.txt: 取代 34213 筆
# od/v4/val.txt: 取代 2364 筆
# od/v4/multiple_val.txt: 取代 116 筆
# 完成
