# %%
import json
import random
import shutil
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path

import cv2
import numpy as np
from PIL import Image

from ultralytics.utils import DATASETS_DIR, LOGGER, NUM_THREADS, TQDM
from ultralytics.utils.downloads import download, zip_directory
from ultralytics.utils.files import increment_path

# %%
def convert_segment_masks_to_yolo_seg(masks_dir, output_dir, classes):
    """
    Converts a dataset of segmentation mask images to the YOLO segmentation format.

    This function takes the directory containing the binary format mask images and converts them into YOLO segmentation format.
    The converted masks are saved in the specified output directory.

    Args:
        masks_dir (str): The path to the directory where all mask images (png, jpg) are stored.
        output_dir (str): The path to the directory where the converted YOLO segmentation masks will be stored.
        classes (int): Total classes in the dataset i.e. for COCO classes=80

    Examples:
        >>> from ultralytics.data.converter import convert_segment_masks_to_yolo_seg

        The classes here is the total classes in the dataset, for COCO dataset we have 80 classes
        >>> convert_segment_masks_to_yolo_seg("path/to/masks_directory", "path/to/output/directory", classes=80)

    Notes:
        The expected directory structure for the masks is:

            - masks
                ├─ mask_image_01.png or mask_image_01.jpg
                ├─ mask_image_02.png or mask_image_02.jpg
                ├─ mask_image_03.png or mask_image_03.jpg
                └─ mask_image_04.png or mask_image_04.jpg

        After execution, the labels will be organized in the following structure:

            - output_dir
                ├─ mask_yolo_01.txt
                ├─ mask_yolo_02.txt
                ├─ mask_yolo_03.txt
                └─ mask_yolo_04.txt
    """
    pixel_to_class_mapping = {i + 1: i for i in range(classes)}
    for mask_path in Path(masks_dir).iterdir():
        if mask_path.suffix in {".png", ".jpg"}:
            mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)  # Read the mask image in grayscale
            mask = (mask > 127).astype(np.uint8)
            img_height, img_width = mask.shape  # Get image dimensions
            LOGGER.info(f"Processing {mask_path} imgsz = {img_height} x {img_width}")

            unique_values = np.unique(mask)  # Get unique pixel values representing different classes
            yolo_format_data = []
            print("unique_values : ", unique_values)
            for value in unique_values:
                if value == 0:
                    continue  # Skip background
                class_index = pixel_to_class_mapping.get(value, -1)
                if class_index == -1:
                    LOGGER.warning(f"Unknown class for pixel value {value} in file {mask_path}, skipping.")
                    continue

                # Create a binary mask for the current class and find contours
                contours, _ = cv2.findContours(
                    (mask == value).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
                )  # Find contours

                for contour in contours:
                    if len(contour) >= 3:  # YOLO requires at least 3 points for a valid segmentation
                        contour = contour.squeeze()  # Remove single-dimensional entries
                        yolo_format = [class_index]
                        for point in contour:
                            # Normalize the coordinates
                            yolo_format.append(round(point[0] / img_width, 6))  # Rounding to 6 decimal places
                            yolo_format.append(round(point[1] / img_height, 6))
                        yolo_format_data.append(yolo_format)
            # Save Ultralytics YOLO format data to file
            output_path = Path(output_dir) / f"{mask_path.stem}.txt"
            with open(output_path, "w", encoding="utf-8") as file:
                for item in yolo_format_data:
                    line = " ".join(map(str, item))
                    file.write(line + "\n")
            LOGGER.info(f"Processed and stored at {output_path} imgsz = {img_height} x {img_width}")

# %%
# For datasets like COCO with 80 classes
convert_segment_masks_to_yolo_seg(masks_dir="YOLO_data/masks/train/", output_dir="YOLO_data/labels/train/", classes=256)
# Out:
# Processing YOLO_data\masks\train\TG3K_0.jpg imgsz = 191 x 265
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TG3K
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_921.txt imgsz = 336 x 281
# Processing YOLO_data\masks\train\TN3K_922.jpg imgsz = 303 x 281
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_922.txt imgsz = 303 x 281
# Processing YOLO_data\masks\train\TN3K_923.jpg imgsz = 338 x 328
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_923.txt imgsz = 338 x 328
# Processing YOLO_data\masks\train\TN3K_924.jpg imgsz = 335 x 326
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_924.txt imgsz = 335 x 326
# Processing YOLO_data\masks\train\TN3K_925.jpg imgsz = 378 x 303
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_925.txt imgsz = 378 x 303
# Processing YOLO_data\masks\train\TN3K_926.jpg imgsz = 312 x 304
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_926.txt imgsz = 312 x 304
# Processing YOLO_data\masks\train\TN3K_927.jpg imgsz = 388 x 374
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_927.txt imgsz = 388 x 374
# Processing YOLO_data\masks\train\TN3K_928.jpg imgsz = 372 x 394
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_928.txt imgsz = 372 x 394
# Processing YOLO_data\masks\train\TN3K_929.jpg imgsz = 396 x 446
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_929.txt imgsz = 396 x 446
# Processing YOLO_data\masks\train\TN3K_93.jpg imgsz = 361 x 376
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_93.txt imgsz = 361 x 376
# Processing YOLO_data\masks\train\TN3K_930.jpg imgsz = 388 x 427
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_930.txt imgsz = 388 x 427
# Processing YOLO_data\masks\train\TN3K_931.jpg imgsz = 405 x 395
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_931.txt imgsz = 405 x 395
# Processing YOLO_data\masks\train\TN3K_932.jpg imgsz = 401 x 500
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_932.txt imgsz = 401 x 500
# Processing YOLO_data\masks\train\TN3K_933.jpg imgsz = 376 x 340
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_933.txt imgsz = 376 x 340
# Processing YOLO_data\masks\train\TN3K_934.jpg imgsz = 375 x 342
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_934.txt imgsz = 375 x 342
# Processing YOLO_data\masks\train\TN3K_935.jpg imgsz = 324 x 291
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_935.txt imgsz = 324 x 291
# Processing YOLO_data\masks\train\TN3K_936.jpg imgsz = 318 x 291
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_936.txt imgsz = 318 x 291
# Processing YOLO_data\masks\train\TN3K_937.jpg imgsz = 313 x 290
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_937.txt imgsz = 313 x 290
# Processing YOLO_data\masks\train\TN3K_938.jpg imgsz = 302 x 291
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_938.txt imgsz = 302 x 291
# Processing YOLO_data\masks\train\TN3K_939.jpg imgsz = 299 x 291
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_939.txt imgsz = 299 x 291
# Processing YOLO_data\masks\train\TN3K_94.jpg imgsz = 284 x 336
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_94.txt imgsz = 284 x 336
# Processing YOLO_data\masks\train\TN3K_940.jpg imgsz = 339 x 447
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_940.txt imgsz = 339 x 447
# Processing YOLO_data\masks\train\TN3K_941.jpg imgsz = 273 x 250
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_941.txt imgsz = 273 x 250
# Processing YOLO_data\masks\train\TN3K_942.jpg imgsz = 270 x 253
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_942.txt imgsz = 270 x 253
# Processing YOLO_data\masks\train\TN3K_943.jpg imgsz = 370 x 329
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_943.txt imgsz = 370 x 329
# Processing YOLO_data\masks\train\TN3K_944.jpg imgsz = 380 x 412
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_944.txt imgsz = 380 x 412
# Processing YOLO_data\masks\train\TN3K_945.jpg imgsz = 378 x 413
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_945.txt imgsz = 378 x 413
# Processing YOLO_data\masks\train\TN3K_946.jpg imgsz = 315 x 386
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_946.txt imgsz = 315 x 386
# Processing YOLO_data\masks\train\TN3K_947.jpg imgsz = 324 x 388
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_947.txt imgsz = 324 x 388
# Processing YOLO_data\masks\train\TN3K_948.jpg imgsz = 345 x 332
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_948.txt imgsz = 345 x 332
# Processing YOLO_data\masks\train\TN3K_949.jpg imgsz = 341 x 330
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_949.txt imgsz = 341 x 330
# Processing YOLO_data\masks\train\TN3K_95.jpg imgsz = 280 x 273
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_95.txt imgsz = 280 x 273
# Processing YOLO_data\masks\train\TN3K_950.jpg imgsz = 334 x 410
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_950.txt imgsz = 334 x 410
# Processing YOLO_data\masks\train\TN3K_951.jpg imgsz = 307 x 340
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_951.txt imgsz = 307 x 340
# Processing YOLO_data\masks\train\TN3K_952.jpg imgsz = 315 x 339
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_952.txt imgsz = 315 x 339
# Processing YOLO_data\masks\train\TN3K_953.jpg imgsz = 377 x 429
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_953.txt imgsz = 377 x 429
# Processing YOLO_data\masks\train\TN3K_954.jpg imgsz = 328 x 431
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_954.txt imgsz = 328 x 431
# Processing YOLO_data\masks\train\TN3K_955.jpg imgsz = 292 x 295
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_955.txt imgsz = 292 x 295
# Processing YOLO_data\masks\train\TN3K_956.jpg imgsz = 299 x 410
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_956.txt imgsz = 299 x 410
# Processing YOLO_data\masks\train\TN3K_957.jpg imgsz = 317 x 321
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_957.txt imgsz = 317 x 321
# Processing YOLO_data\masks\train\TN3K_958.jpg imgsz = 320 x 342
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_958.txt imgsz = 320 x 342
# Processing YOLO_data\masks\train\TN3K_959.jpg imgsz = 322 x 339
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_959.txt imgsz = 322 x 339
# Processing YOLO_data\masks\train\TN3K_96.jpg imgsz = 286 x 273
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_96.txt imgsz = 286 x 273
# Processing YOLO_data\masks\train\TN3K_960.jpg imgsz = 374 x 342
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_960.txt imgsz = 374 x 342
# Processing YOLO_data\masks\train\TN3K_961.jpg imgsz = 306 x 345
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_961.txt imgsz = 306 x 345
# Processing YOLO_data\masks\train\TN3K_962.jpg imgsz = 332 x 410
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_962.txt imgsz = 332 x 410
# Processing YOLO_data\masks\train\TN3K_963.jpg imgsz = 326 x 408
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_963.txt imgsz = 326 x 408
# Processing YOLO_data\masks\train\TN3K_964.jpg imgsz = 393 x 273
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_964.txt imgsz = 393 x 273
# Processing YOLO_data\masks\train\TN3K_965.jpg imgsz = 251 x 208
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_965.txt imgsz = 251 x 208
# Processing YOLO_data\masks\train\TN3K_966.jpg imgsz = 293 x 293
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_966.txt imgsz = 293 x 293
# Processing YOLO_data\masks\train\TN3K_967.jpg imgsz = 360 x 333
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_967.txt imgsz = 360 x 333
# Processing YOLO_data\masks\train\TN3K_968.jpg imgsz = 384 x 337
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_968.txt imgsz = 384 x 337
# Processing YOLO_data\masks\train\TN3K_969.jpg imgsz = 333 x 413
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_969.txt imgsz = 333 x 413
# Processing YOLO_data\masks\train\TN3K_97.jpg imgsz = 283 x 268
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_97.txt imgsz = 283 x 268
# Processing YOLO_data\masks\train\TN3K_970.jpg imgsz = 338 x 472
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_970.txt imgsz = 338 x 472
# Processing YOLO_data\masks\train\TN3K_971.jpg imgsz = 367 x 340
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_971.txt imgsz = 367 x 340
# Processing YOLO_data\masks\train\TN3K_972.jpg imgsz = 362 x 342
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_972.txt imgsz = 362 x 342
# Processing YOLO_data\masks\train\TN3K_973.jpg imgsz = 308 x 490
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_973.txt imgsz = 308 x 490
# Processing YOLO_data\masks\train\TN3K_974.jpg imgsz = 307 x 412
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_974.txt imgsz = 307 x 412
# Processing YOLO_data\masks\train\TN3K_975.jpg imgsz = 333 x 409
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_975.txt imgsz = 333 x 409
# Processing YOLO_data\masks\train\TN3K_976.jpg imgsz = 319 x 340
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_976.txt imgsz = 319 x 340
# Processing YOLO_data\masks\train\TN3K_977.jpg imgsz = 328 x 353
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_977.txt imgsz = 328 x 353
# Processing YOLO_data\masks\train\TN3K_978.jpg imgsz = 334 x 346
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_978.txt imgsz = 334 x 346
# Processing YOLO_data\masks\train\TN3K_979.jpg imgsz = 234 x 274
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_979.txt imgsz = 234 x 274
# Processing YOLO_data\masks\train\TN3K_98.jpg imgsz = 341 x 387
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_98.txt imgsz = 341 x 387
# Processing YOLO_data\masks\train\TN3K_980.jpg imgsz = 353 x 434
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_980.txt imgsz = 353 x 434
# Processing YOLO_data\masks\train\TN3K_981.jpg imgsz = 343 x 433
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_981.txt imgsz = 343 x 433
# Processing YOLO_data\masks\train\TN3K_982.jpg imgsz = 342 x 299
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_982.txt imgsz = 342 x 299
# Processing YOLO_data\masks\train\TN3K_983.jpg imgsz = 336 x 315
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_983.txt imgsz = 336 x 315
# Processing YOLO_data\masks\train\TN3K_984.jpg imgsz = 341 x 307
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_984.txt imgsz = 341 x 307
# Processing YOLO_data\masks\train\TN3K_985.jpg imgsz = 335 x 314
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_985.txt imgsz = 335 x 314
# Processing YOLO_data\masks\train\TN3K_986.jpg imgsz = 368 x 448
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_986.txt imgsz = 368 x 448
# Processing YOLO_data\masks\train\TN3K_987.jpg imgsz = 364 x 447
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_987.txt imgsz = 364 x 447
# Processing YOLO_data\masks\train\TN3K_988.jpg imgsz = 279 x 515
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_988.txt imgsz = 279 x 515
# Processing YOLO_data\masks\train\TN3K_989.jpg imgsz = 371 x 387
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_989.txt imgsz = 371 x 387
# Processing YOLO_data\masks\train\TN3K_99.jpg imgsz = 370 x 388
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_99.txt imgsz = 370 x 388
# Processing YOLO_data\masks\train\TN3K_990.jpg imgsz = 317 x 290
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_990.txt imgsz = 317 x 290
# Processing YOLO_data\masks\train\TN3K_991.jpg imgsz = 334 x 295
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_991.txt imgsz = 334 x 295
# Processing YOLO_data\masks\train\TN3K_992.jpg imgsz = 338 x 369
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_992.txt imgsz = 338 x 369
# Processing YOLO_data\masks\train\TN3K_993.jpg imgsz = 338 x 474
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_993.txt imgsz = 338 x 474
# Processing YOLO_data\masks\train\TN3K_994.jpg imgsz = 336 x 472
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_994.txt imgsz = 336 x 472
# Processing YOLO_data\masks\train\TN3K_995.jpg imgsz = 262 x 274
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_995.txt imgsz = 262 x 274
# Processing YOLO_data\masks\train\TN3K_996.jpg imgsz = 322 x 412
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_996.txt imgsz = 322 x 412
# Processing YOLO_data\masks\train\TN3K_997.jpg imgsz = 373 x 388
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_997.txt imgsz = 373 x 388
# Processing YOLO_data\masks\train\TN3K_998.jpg imgsz = 368 x 390
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_998.txt imgsz = 368 x 390
# Processing YOLO_data\masks\train\TN3K_999.jpg imgsz = 337 x 415
# unique_values :  [0 1]
# Processed and stored at YOLO_data\labels\train\TN3K_999.txt imgsz = 337 x 415
